# %%
from langchain_groq import ChatGroq
from langgraph.graph import StateGraph, START, END
from dotenv import load_dotenv
from typing import TypedDict

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGroq(model="llama-3.3-70b-versatile")

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState)->BlogState:
    title= state['title']
    prompt=f"generate an detailed outline for a blog on the topic {title}"
    result=model.invoke(prompt).content
    state['outline']=result
    return state

# %%
def create_blog(state: BlogState)-> BlogState:
    title=state['title']
    outline= state['outline']

    prompt=f"write a blog on the title {title} using the detailed outline {outline}"
    result= model.invoke(prompt).content
    state['content']=result
    return state

# %%
graph=StateGraph(BlogState)
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)
workflow= graph.compile()

# %%
workflow.invoke({'title':"flowers are beautiful"})
# Out:
# {'title': 'flowers are beautiful',
#  'outline': '**Title:** "The Timeless Beauty of Flowers: Unveiling Their Charm and Significance"\n\n**I. Introduction**\n\n* Brief overview of the beauty and significance of flowers\n* Importance of flowers in human life and culture\n* Thesis statement: Flowers are not only visually stunning but also hold deep symbolic meanings, emotional connections, and practical uses, making them an integral part of our lives.\n\n**II. The Aesthetic Appeal of Flowers**\n\n* Description of the diverse range of flower colors, shapes, and sizes\n* Discussion of the role of flowers in art, design, and decoration\n* Examples of how flowers are used in various forms of creative expression (e.g., photography, painting, floral arrangements)\n* Subpoints:\n\t+ The impact of flowers on interior design and home decor\n\t+ The use of flowers in fashion and accessories (e.g., flower crowns, floral patterns)\n\n**III. The Symbolic Meaning of Flowers**\n\n* Overview of the language of flowers (floriography) and its history\n* Explanation of common flower symbols and their meanings (e.g., red roses for love, white lilies for purity)\n* Discussion of how flowers are used to convey emotions and messages on various occasions (e.g., weddings, funerals, birthdays)\n* Subpoints:\n\t+ The cultural significance of flowers in different societies and traditions\n\t+ The use of flowers in rituals and ceremonies (e.g., wedding bouquets, funeral wreaths)\n\n**IV. The Emotional Connection to Flowers**\n\n* Personal stories and anecdotes about the significance of flowers in people\'s lives\n* Discussion of the psychological benefits of being around flowers (e.g., stress reduction, mood improvement)\n* Explanation of how flowers can evoke emotions and create memories (e.g., the smell of a particular flower reminding someone of a special event)\n* Subpoints:\n\t+ The role of flowers in therapy and counseling (e.g., horticultural therapy)\n\t+ The impact of flowers on mental health and well-being\n\n**V. The Practical Uses of Flowers**\n\n* Overview of the various uses of flowers beyond their aesthetic appeal (e.g., medicinal, culinary, cosmetic)\n* Discussion of the benefits of flowers in traditional medicine and herbalism\n* Examples of edible flowers and their uses in cooking and baking\n* Subpoints:\n\t+ The use of flowers in skincare and beauty products (e.g., rosewater, lavender oil)\n\t+ The role of flowers in perfumery and fragrance creation\n\n**VI. Conclusion**\n\n* Recap of the beauty, significance, and versatility of flowers\n* Final thoughts on the importance of appreciating and preserving flowers in our lives and environment\n* Call to action: Encouragement to explore and learn more about the world of flowers, and to find ways to incorporate them into daily life.\n\n**Additional Ideas:**\n\n* Include high-quality images of flowers throughout the blog post to illustrate the points being made\n* Provide links to resources or further reading on the topics discussed\n* Offer tips and suggestions for growing, caring for, and arranging flowers\n* Share personal anecdotes or stories from readers about their favorite flowers or flower-related experiences.',
#  'content': "**The Timeless Beauty of Flowers: Unveiling Their Charm and Significance**\n\nFlowers have been a staple of human life and culture for centuries, captivating our senses with their breathtaking beauty and profound significance. From the intricate details of their petals to the symbolic meanings they convey, flowers have become an integral part of our daily lives. They are not only visually stunning but also hold deep symbolic meanings, emotional connections, and practical uses, making them an essential aspect of our lives. In this blog, we will delve into the world of flowers, exploring their aesthetic appeal, symbolic meanings, emotional connections, practical uses, and the impact they have on our lives.\n\n**The Aesthetic Appeal of Flowers**\n\nThe diversity of flowers is truly astounding, with a vast array of colors, shapes, and sizes to choose from. From the delicate petals of a rose to the vibrant hues of a sunflower, flowers have the power to evoke emotions and inspire creativity. In the world of art, design, and decoration, flowers play a significant role, with many artists, designers, and decorators incorporating them into their work. For example, photographers often use flowers as subjects, capturing their intricate details and beauty. Painters, on the other hand, use flowers as inspiration for their brushstrokes and color palettes. Floral arrangements, too, are a popular way to showcase the beauty of flowers, with many people using them to decorate their homes and special events.\n\nThe impact of flowers on interior design and home decor is also noteworthy. Flowers can add a touch of elegance and sophistication to any room, with many people using them to create beautiful centerpieces and arrangements. In fashion and accessories, flowers are also used to create stunning pieces, such as flower crowns and floral patterns. The use of flowers in fashion and accessories has become increasingly popular, with many designers incorporating them into their designs.\n\n**The Symbolic Meaning of Flowers**\n\nFlowers have been used for centuries to convey emotions and messages, with each type of flower having its own unique meaning. The language of flowers, also known as floriography, has a rich history, dating back to ancient civilizations. In this language, flowers are used to express emotions, thoughts, and ideas, with different flowers representing different meanings. For example, red roses are often associated with love and passion, while white lilies are associated with purity and innocence.\n\nFlowers are also used to convey emotions and messages on various occasions, such as weddings, funerals, and birthdays. On these occasions, flowers are often used to express sympathy, condolences, or congratulations. In different cultures and societies, flowers have significant meanings and uses, with many cultures using them in rituals and ceremonies. For example, in many Asian cultures, flowers are used in wedding ceremonies to symbolize good luck and prosperity.\n\n**The Emotional Connection to Flowers**\n\nFlowers have a way of evoking emotions and creating memories, with many people having a personal connection to a particular type of flower. For example, the smell of a rose may remind someone of their grandmother, while the sight of a sunflower may evoke feelings of happiness and joy. The psychological benefits of being around flowers are also well-documented, with studies showing that flowers can reduce stress, improve mood, and boost cognitive function.\n\nFlowers are also used in therapy and counseling, with many therapists using them as a tool to help patients express their emotions and work through challenging experiences. The use of flowers in horticultural therapy, for example, has been shown to have a positive impact on mental health and well-being. By working with flowers, patients can develop a sense of purpose and self-esteem, while also improving their mental and emotional health.\n\n**The Practical Uses o ...
