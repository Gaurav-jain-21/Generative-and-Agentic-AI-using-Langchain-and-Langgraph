# %%
from langgraph.graph import StateGraph, START, END
from langchain_groq import ChatGroq
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model= ChatGroq(model="llama-3.1-8b-instant")

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState)-> BlogState:
    title= state['title']
    prompt=f'Generate an outline for a blog on the title - {title}'
    outline=model.invoke(prompt).content
    state['outline']=outline
    return state

# %%
def create_blog(state: BlogState)-> BlogState:
    title = state['title']
    outline=state['outline']
    prompt = f'write a detailed blog on the title - {title} using the following outline {outline}'
    content = model.invoke(prompt).content
    state['content']= content
    return state

# %%
graph= StateGraph(BlogState)
graph.add_node('create_outline',create_outline)
graph.add_node('create_blog',create_blog)
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)
workflow=graph.compile()

# %%
workflow.invoke({'title':'cricket'})
# Out:
# {'title': 'cricket',
#  'outline': "Here's an outline on the topic of Cricket:\n\n**I. Introduction to Cricket**\n\n- A. Definition: Cricket is a popular team sport played with a bat, ball, and wickets.\n- B. Origins: Cricket originated in England in the 16th century.\n- C. Global Reach: Cricket is played in over 100 countries, with a massive following in the UK, India, Australia, and the Caribbean.\n\n**II. Objective of Cricket**\n\n- A. Basic Objective: The objective of cricket is to score runs by hitting the ball with the bat and running between the wickets.\n- B. Scoring System: Runs are scored when a batsman reaches the opposite end of the pitch without being dismissed.\n- C. Winning Conditions: The team with the higher score at the end of the game wins.\n\n**III. Equipment Used in Cricket**\n\n- A. Ball: The ball is made of leather or synthetic materials and weighs between 155.9 and 163 grams.\n- B. Bat: The bat is made of wood or materials like aluminum and weighs between 950 and 1260 grams.\n- C. Wickets: The wickets consist of three vertical stumps and two horizontal stumps.\n- D. Protective Gear: Players wear protective gear like helmets, pads, and gloves to prevent injuries.\n\n**IV. Positions in Cricket**\n\n- A. Batsmen: The batsmen are responsible for scoring runs and facing the bowler.\n- B. Bowlers: The bowlers deliver the ball towards the batsman and try to dismiss them.\n- C. Fielders: The fielders are responsible for catching the ball and dismissing the batsman.\n- D. Wicketkeeper: The wicketkeeper stands behind the wickets and is responsible for dismissing the batsman.\n\n**V. Types of Cricket**\n\n- A. Test Cricket: The longest and most prestigious form of cricket, played over five days.\n- B. One-Day Internationals (ODIs): A shorter version of cricket, played in a single day.\n- C. Twenty20 (T20): A shorter version of cricket, played over 20 overs.\n\n**VI. Cricket Techniques**\n\n- A. Batting Techniques: Various techniques like driving, cutting, and hooking are used to score runs.\n- B. Bowling Techniques: Various techniques like fast bowling, spin bowling, and swing bowling are used to dismiss the batsman.\n- C. Fielding Techniques: Various techniques like catching, throwing, and running are used to dismiss the batsman.\n\n**VII. Cricket Rules and Regulations**\n\n- A. Laws of Cricket: The laws of cricket are governed by the International Cricket Council (ICC).\n- B. Scoring System: The scoring system is governed by the ICC and is used to keep track of runs and dismissals.\n- C. Dismissals: Various methods like bowled, caught, stumped, and run out are used to dismiss the batsman.\n\n**VIII. Cricket Tournaments and Leagues**\n\n- A. International Tournaments: The ICC World Cup, the Ashes, and the Indian Premier League (IPL) are some of the most popular cricket tournaments.\n- B. Domestic Leagues: Leagues like the County Championship in England, the Sheffield Shield in Australia, and the Ranji Trophy in India are popular domestic cricket leagues.\n\n**IX. Conclusion**\n\n- A. Cricket is a popular team sport played with a bat, ball, and wickets.\n- B. Cricket is played in over 100 countries and has a massive following.\n- C. Cricket is a sport that requires skill, strategy, and physical fitness.",
#  'content': '**The Game of Kings: A Comprehensive Guide to Cricket**\n\nCricket is a popular team sport played with a bat, ball, and wickets. It is a sport that has been enjoyed by millions of people around the world for centuries, and its global reach is unparalleled. In this blog, we will delve into the world of cricket, exploring its origins, objective, equipment, positions, types, techniques, rules, and tournaments.\n\n**I. Introduction to Cricket**\n\n### Definition\n\nCricket is a bat-and-ball game played between two teams of eleven players each. The game involves a bat, a ball, and wickets, which are three vertical stumps and two horizontal stumps. The objective of the game is to score runs by hitting the ball with the bat and running between the wickets.\n\n### Origins\n\nCricket originated in England in the 16th century, with the first recorded match taking place in 1598. The game was initially played by the upper class, but it soon became a popular sport among the masses. Today, cricket is played in over 100 countries, with a massive following in the UK, India, Australia, and the Caribbean.\n\n### Global Reach\n\nCricket is one of the most popular sports in the world, with a massive following in many countries. The International Cricket Council (ICC) is the governing body of the sport, and it has a membership of 125 countries. The ICC has played a crucial role in promoting the sport and organizing international tournaments.\n\n**II. Objective of Cricket**\n\n### Basic Objective\n\nThe basic objective of cricket is to score runs by hitting the ball with the bat and running between the wickets. The team with the higher score at the end of the game wins.\n\n### Scoring System\n\nRuns are scored when a batsman reaches the opposite end of the pitch without being dismissed. The scoring system is based on the number of runs scored by each batsman, and it is governed by the ICC.\n\n### Winning Conditions\n\nThe team with the higher score at the end of the game wins. If the scores are tied, the game may go into a super over, where the team with the higher score in the super over wins.\n\n**III. Equipment Used in Cricket**\n\n### Ball\n\nThe ball is made of leather or synthetic materials and weighs between 155.9 and 163 grams. The ball is designed to be aerodynamic, and it must meet certain specifications to be used in international cricket.\n\n### Bat\n\nThe bat is made of wood or materials like aluminum and weighs between 950 and 1260 grams. The bat is designed to be durable and must meet certain specifications to be used in international cricket.\n\n### Wickets\n\nThe wickets consist of three vertical stumps and two horizontal stumps. The wickets are designed to be durable and must meet certain specifications to be used in international cricket.\n\n### Protective Gear\n\nPlayers wear protective gear like helmets, pads, and gloves to prevent injuries. The protective gear is designed to be durable and must meet certain specifications to be used in international cricket.\n\n**IV. Positions in Cricket**\n\n### Batsmen\n\nThe batsmen are responsible for scoring runs and facing the bowler. There are two types of batsmen: the opener and the middle-order batsman.\n\n### Bowlers\n\nThe bowlers are responsible for delivering the ball towards the batsman and trying to dismiss them. There are two types of bowlers: the fast bowler and the spin bowler.\n\n### Fielders\n\nThe fielders are responsible for catching the ball and dismissing the batsman. There are several types of fielders, including the wicketkeeper, the slips, and the gully.\n\n### Wicketkeeper\n\nThe wicketkeeper stands behind the wickets and is responsible for dismissing the batsman. The wicketkeeper is an important member of the team and must have good hand-eye coordination and agility.\n\n**V. Types of Cricket**\n\n### Test Cricket\n\nTest cricket is the longest and most prestigious form of cricket, played over five days. The game is played between two teams, and each te ...
