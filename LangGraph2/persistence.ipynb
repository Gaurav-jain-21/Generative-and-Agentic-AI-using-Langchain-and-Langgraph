# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_groq import ChatGroq
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver

# %%
load_dotenv()
llm = ChatGroq(model= "llama-3.1-8b-instant")

# %%
class JokeState(TypedDict):
    topic : str
    joke :  str
    explanation: str

# %%
def generate_joke(state: JokeState):
    prompt=f'generate a joke on the topic {state['topic']}'
    response= llm.invoke(prompt).content
    return {'joke': response}

# %%
def generate_explanation(state: JokeState):
    prompt = f'Write an explanation for the joke {state['joke']}'
    response= llm.invoke(prompt).content
    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke',generate_joke)
graph.add_node('generate_explanation',generate_explanation)


graph.add_edge(START,'generate_joke')
graph.add_edge('generate_joke','generate_explanation')
graph.add_edge('generate_explanation',END)

checkpointer= InMemorySaver()
workflow= graph.compile(checkpointer=checkpointer)

# %%
config1= {"configurable": {"thread_id":"1"}}
workflow.invoke({'topic':'pizza'},config= config1)
# Out:
# {'topic': 'pizza',
#  'joke': 'Why did the pizza go to the doctor?\n\nBecause it was feeling a little crusty.',
#  'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses the double meaning of the word "crusty" to create a pun.\n\nIn this context, "crusty" refers to the crusty part of a pizza, which is a common characteristic of this type of food. However, "crusty" can also mean feeling irritable or having a rough temper, which is a common reason for visiting a doctor.\n\nThe joke relies on this wordplay to create a pun, making it a lighthearted and amusing play on language. The use of a pizza, a relatable and familiar food item, as the subject of the joke makes it more accessible and easier to understand. The punchline, "Because it was feeling a little crusty," is a clever and unexpected twist on the typical doctor visit, making it a humorous and entertaining joke.'}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor?\n\nBecause it was feeling a little crusty.', 'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses the double meaning of the word "crusty" to create a pun.\n\nIn this context, "crusty" refers to the crusty part of a pizza, which is a common characteristic of this type of food. However, "crusty" can also mean feeling irritable or having a rough temper, which is a common reason for visiting a doctor.\n\nThe joke relies on this wordplay to create a pun, making it a lighthearted and amusing play on language. The use of a pizza, a relatable and familiar food item, as the subject of the joke makes it more accessible and easier to understand. The punchline, "Because it was feeling a little crusty," is a clever and unexpected twist on the typical doctor visit, making it a humorous and entertaining joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f17b7a4-e925-661a-8002-fc790eac63f8'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-07-09T09:41:05.963560+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f17b7a4-e54a-65ad-8001-205e24ab4c2e'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor?\n\nBecause it was feeling a little crusty.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f17b7a4-e54a-65ad-8001-205e24ab4c2e'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-07-09T09:41:05.559269+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f17b7a4-df20-63d3-8000-1bdd9474ffab'}}, tasks=(PregelTask(id='813e2e46-dc8d-f89e-d1e8-bed23247741f', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses the double meaning of the word "crusty" to create a pun.\n\nIn this context, "crusty" refers to the crusty part of a pizza, which is a common characteristic of this type of food. However, "crusty" can also mean feeling irritable or having a rough temper, which is a common reason for visiting a doctor.\n\nThe joke relies on this wordplay to create a pun, making it a lighthearted and amusing play on language. The use of a pizza, a relatable and familiar food item, as the subject of the joke makes it more accessible and easier to understand. The punchline, "Because it was feeling a little crusty," is a clever and unexpected twist on the typical doctor visit, making it a humorous and entertaining joke.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f17b7a4-df20-63d3-8000-1bdd9474ffab'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-07-09T09:41:04.912873+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f17b7a4-df02-6c60-bfff-c5fc6e401a06'}}, tasks=(PregelTask(id='a6a0a71a-3939-d333-a486-609c350ccfcd', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza go to the doctor?\n\nBecause it was feeling a little crusty.'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f17b7a4-df02-6c60-bfff-c5fc6e401a06'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-07-09T09:41:04.900750+00:00', parent_config=None, tasks=(PregelTask(id='f5eecf68-269f-6793-b48d-81da1bc97f78', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %%
config2= {'configurable': {'thread_id': "2"}}
workflow.invoke({'topic': 'pasta'},config= config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the spaghetti go to therapy? \n\nBecause it was feeling a little twisted.',
#  'explanation': 'The joke "Why did the spaghetti go to therapy? Because it was feeling a little twisted" is a play on words. It uses a pun to create humor. \n\nThe phrase "feeling a little twisted" has a double meaning here. In a literal sense, twisted can refer to the fact that spaghetti is a long, thin, cylindrical pasta that is often twisted and turned into various shapes. However, in an idiomatic sense, "feeling twisted" can also mean being emotionally or psychologically troubled or unstable.\n\nThe joke relies on this dual meaning to create a pun, where the word "twisted" is used to make a connection between the physical properties of spaghetti and its emotional state, creating a humorous and unexpected twist (pun intended). The joke requires a basic understanding of the wordplay involved, but the simplicity and cleverness of the pun make it an effective and amusing joke.'}
