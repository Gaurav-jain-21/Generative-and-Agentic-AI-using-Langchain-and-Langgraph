# %%
from langgraph.graph import StateGraph, START, END
from langchain_groq import ChatGroq
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model= ChatGroq(model="llama-3.1-8b-instant")

# %%
class LLMState(TypedDict):
    question:str
    answer: str

# %%
def llm_qa(state: LLMState) -> LLMState:
    question = state['question']
    prompt = f'Answer the following question: {question}'

    answer = model.invoke(prompt).content
    state['answer'] = answer

    return state

# %%
# createt our graph
graph= StateGraph(LLMState)

graph.add_node('llm_qa',llm_qa)

graph.add_edge(START, 'llm_qa')
graph.add_edge('llm_qa',END)
workflow=graph.compile()

# %%
workflow.invoke({'question':"how wrote the song we dont talk anymore"})
# Out:
# {'question': 'how wrote the song we dont talk anymore',
#  'answer': 'The song "We Don\'t Talk Anymore" is a duet by British singer Charlie Puth and Dutch DJ Wulf, however it is more famously known for being a collaboration with the singer and DJ known as a feature from the artist, Dutch DJ and producer, \'Wulf\' not known as a DJ but an artist named \'Wulf\' but in this song the artist known as a singer and DJ is actually a collaboration with the DJ known as \'Seeb\', however, I believe that the question you were asking was in reference to the song that is known as a feature of the singer Charlie Puth, and I believe the actual DJ in the song that is known as a feature of the singer Charlie Puth is actually the DJ and artist, known as \'Seeb\'.\n\nThe song was written by:\n\n- Alexander Schultz-Johansen (of the duo Seeb)\n- Morten Hjort (of the duo Seeb)\n- Charlie Puth\n- Jacob Hazell'}
